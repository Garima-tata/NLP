# %% [markdown]
# # Word Embeddings
#
# In NLP, Word embedding is a term used for the represenetaion of words for text analysis, typically in the form of a real valued vector that encodes the meaning of the word such that the words that are closer in the vector space are expected to be similar in meaning.
#
# ```
#                         Types
#             frequency           prediction
# (frequency count ke basis       (word to vector conversion depends on
# pe vector represent karte ho)   some algorithm ke predictions, mostly Deep learning)
#         - BOW
#         - TF=IDF                       - Word2Vec
#         - Glove(Matrix
#          factorization)
# ```

# %% [markdown]
# # Word2Vec
#
# it is a word embedding technique which is used to convert words into vectors(collection of numbers). as we can't use text directly for training a model so we use word2vec to convert text into numbers.
#
#
# - You can find out the semantic meaning of text. exmple: happy and joy are similar.
# - Low dimension vectors bante, to computation fast ho jaata hai
# - Dense vectors bante hai prevents overfitting.
#
# but previous BOW, TFidf ki tarah high dimensional vector nhi bante, sparse hote the toh computation and overfitting was the problem now solved by Word2Vec.

# %%
## demo is in file WordToVec.ipynb

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image-3.png)
# ![image.png](attachment:image-4.png)
# ![image.png](attachment:image-5.png)

# %% [markdown]
# ### The window size determines the span of words on either side of a target_word that can be considered a context word. Below is a table of skip-grams for target words based on different window sizes.
#
#
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## CBOW

# %% [markdown]
# ![image.png](attachment:image-3.png)
# we want to convert each word in 3 dimensional vectors. predict on context: watch = [0.6, 0.1, 1.2],
#
# GIVEN CONTEXT WORD PREDICT TARGET WORD: WONDOW SIZE = 3 = _ _ _ TARGET _ _ _.
#
# IF WS = 1 == _TARGET _.
#
# ![image.png](attachment:image-7.png)
# CONVERT WORDS IN ONE HOT ENCONCODED VECTORS.
# ```
# WATCH CAMPUSX FOR DATA SCIENCE.  WINDOW SIZE = 3.
#         _(X1)_ TARGET(Y) _(X2)_.
#
# X               Y
# WATCH, FOR     CAMPUSX
# CAMPUSX, DATA  FOR
# FOR, SCIENCE   DATA
#
# ```
# ONE HOT ENCODES: ![image.png](attachment:image-4.png)
#
# ![image.png](attachment:image-5.png)
#
#
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
#
# FOR SOME EPOCHS WE WILL ADJUST THE WEIGHTS.
#
# Vector representation of each word will be the weights coming out of the middle layer of hidden nodes = 3. watch = [w1, w2, w3]
#
# ![image.png](attachment:image-6.png)

# %% [markdown]
# ## SKIPGRAM

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - increase the training.
# - increase dimension of vectors.
# - increase window size.
